# %%
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt
import random


def test(img_size=256 ,number_pochs = 3,img_dir = r"C:\Users\tahas\OneDrive\Desktop\Pro\chest_xray\test",f_names = ['NORMAL','PNEUMONIA']):
    values = number_pochs  
    for name in class_name:
        path = os.path.join(img_dir,name)
        class_ind = class_name.index(name)
        print('i')
        for img in os.listdir(path):
            if values>0:
                img_array = cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
                plt.imshow(img_array)
                plt.show()
                n_img = np.resize(img_array(img_size,img_size))
                n_img = n_img/255
                n_img.reshape(-1 ,img_size,img_size,1)
                values -=1
                return n_img,class_ind
            else:
                break
test()

# %%
model = tf.keras.models.load_model('X-ray-64x2-CNN')

# %%
prediction = model.predict([test()])
print(f_names[int(prediction[0][0])])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-bb22453cc962> in <module>
# ----> 1 prediction = model.predict([test()])
#       2 print(f_names[int(prediction[0][0])])
#
# ~\anaconda3\envs\gputest\lib\site-packages\tensorflow_core\python\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1011         max_queue_size=max_queue_size,
#    1012         workers=workers,
# -> 1013         use_multiprocessing=use_multiprocessing)
#    1014
#    1015   def reset_metrics(self):
#
# ~\anaconda3\envs\gputest\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in predict(self, model, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing, **kwargs)
#     496         model, ModeKeys.PREDICT, x=x, batch_size=batch_size, verbose=verbose,
# ...

# %%
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt


CATA = ['NORMAL','PNEUMONIA']

def prepare(filename):
    img_size = 256
    img_array = cv2.imread(filename, cv2.IMREAD_GRAYSCALE)
    plt.imshow(img_array, cmap = "gray")
    plt.show()
    new_array = cv2.resize(img_array,(img_size, img_size))
    return new_array.reshape(-1, img_size, img_size, 1)
                           
model = tf.keras.models.load_model("X-raay-64x2-CNN")
                           
                           
prediction = model.predict([prepare(r"C:\Users\tahas\OneDrive\Desktop\Pro\chest_xray\test\PNEUMONIA\person152_bacteria_722.jpeg")])
print(CATA[int(prediction[0][0])])
# Out:
# PNEUMONIA

# %%
prediction = model.predict([prepare(r"C:\Users\tahas\OneDrive\Desktop\Pro\chest_xray\test\NORMAL\IM-0006-0001.jpeg")])
print(CATA[int(prediction[0][0])])
print(prediction)
# Out:
# PNEUMONIA
# [[1.]]
